# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Load and explore the data for Tableau readiness.

# %% [markdown]
# ### TABLE OF CONTENTS:
#
# - [TABLE 1 - Summary](#table-1-summary:)
# - [TABLE 2 - Global Totals](#table-2-global-totals:)
# - [TABLE 3 - Age Groups](#table-3-age-groups:)
# - [TABLE 4 - Ages 0-4](#table-4-ages-0-4:)
# - [TABLE 5 - Ages 5-14](#table-5-ages-5-14:)
# - [TABLE 6 - Ages 15-49](#table-6-ages-15-49:)
# - [TABLE 7 - Ages 50-69](#table-5-ages-50-69:)
# - [TABLE 8 - Ages 70+](#table-8-ages-70+:)
# - [TABLE 9 - Risks](#table-9-risks:)

# %% [markdown]
# ----
#
# <a name="table-1-summary:"/>
#
# #### TABLE 1 Summary:

# %%
summary_df = pd.read_csv('../data/W4P3_COD_V2.0.csv')
summary_df.head()
# Out:
#                       Causes name  \
# 0                      Meningitis
# 1                       Neoplasms
# 2  Fire, heat, and hot substances
# 3                         Malaria
# 4                        Drowning
#
#                              Causes Full Description  Death Numbers  \
# 0  Deaths - Meningitis - Sex: Both - Age: All Age...         2933.0
# 1  Deaths - Neoplasms - Sex: Both - Age: All Ages...        15925.0
# 2  Deaths - Fire, heat, and hot substances - Sex:...          481.0
# 3  Deaths - Malaria - Sex: Both - Age: All Ages (...          393.0
# 4  Deaths - Drowning - Sex: Both - Age: All Ages ...         2127.0
#
#         Entity Code  Year
# 0  Afghanistan  AFG  2007
# 1  Afghanistan  AFG  2007
# 2  Afghanistan  AFG  2007
# 3  Afghanistan  AFG  2007
# 4  Afghanistan  AFG  2007

# %%
summary_df.shape
# Out:
# (201762, 6)

# %%
codes = summary_df['Code'].unique()
len(codes)
# Out:
# 211

# %%
type(values[0])
# Out:
# numpy.float64

# %%
death_totals = summary_df[['Code', 'Year', 'Death Numbers']].groupby(['Code', 'Year']).sum()
death_totals.head()
# Out:
#            Death Numbers
# Code Year
# AFG  1990       147983.0
#      1991       156912.0
#      1992       169205.0
#      1993       182230.0
#      1994       194817.0

# %%
death_totals.merge(summary_df['Death Numbers'])
death_totals['perc_deaths'] =
# Out:
# 0          2933.0
# 1         15925.0
# 2           481.0
# 3           393.0
# 4          2127.0
#            ...
# 201757     4437.0
# 201758      136.0
# 201759      812.0
# 201760      232.0
# 201761        NaN
# Name: Death Numbers, Length: 201762, dtype: float64

# %%
death_totals = death_totals.to_dict()
death_totals = death_totals['Death Numbers']
death_totals
# Out:
# {('AFG', 1990): 147983.0,
#  ('AFG', 1991): 156912.0,
#  ('AFG', 1992): 169205.0,
#  ('AFG', 1993): 182230.0,
#  ('AFG', 1994): 194817.0,
#  ('AFG', 1995): 196533.0,
#  ('AFG', 1996): 198390.0,
#  ('AFG', 1997): 206468.0,
#  ('AFG', 1998): 219778.0,
#  ('AFG', 1999): 204468.0,
#  ('AFG', 2000): 203276.0,
#  ('AFG', 2001): 205366.0,
#  ('AFG', 2002): 202742.0,
#  ('AFG', 2003): 207946.0,
#  ('AFG', 2004): 208130.0,
#  ('AFG', 2005): 206883.0,
#  ('AFG', 2006): 206251.0,
#  ('AFG', 2007): 204812.0,
#  ('AFG', 2008): 200226.0,
#  ('AFG', 2009): 195927.0,
#  ('AFG', 2010): 196341.0,
#  ('AFG', 2011): 196561.0,
#  ('AFG', 2012): 200377.0,
#  ('AFG', 2013): 202992.0,
#  ('AFG', 2014): 211375.0,
#  ('AFG', 2015): 217940.0,
#  ('AFG', 2016): 223718.0,
#  ('AFG', 2017): 217207.0,
#  ('AFG', 2018): 219391.0,
#  ('AFG', 2019): 217641.0,
#  ('AGO', 1990): 161538.0,
#  ('AGO', 1991): 162044.0,
#  ('AGO', 1992): 166792.0,
#  ('AGO', 1993): 181476.0,
#  ('AGO', 1994): 177888.0,
# ...

# %%
summary_df.head()
# Out:
#                       Causes name  \
# 0                      Meningitis
# 1                       Neoplasms
# 2  Fire, heat, and hot substances
# 3                         Malaria
# 4                        Drowning
#
#                              Causes Full Description  Death Numbers  \
# 0  Deaths - Meningitis - Sex: Both - Age: All Age...         2933.0
# 1  Deaths - Neoplasms - Sex: Both - Age: All Ages...        15925.0
# 2  Deaths - Fire, heat, and hot substances - Sex:...          481.0
# 3  Deaths - Malaria - Sex: Both - Age: All Ages (...          393.0
# 4  Deaths - Drowning - Sex: Both - Age: All Ages ...         2127.0
#
#         Entity Code  Year
# 0  Afghanistan  AFG  2007
# 1  Afghanistan  AFG  2007
# 2  Afghanistan  AFG  2007
# 3  Afghanistan  AFG  2007
# 4  Afghanistan  AFG  2007

# %%
# Out:
# 2
# ['ZWE', 2019]

# %%
code = summary_df['Code']
year = summary_df['Year']
keys = zip(code, year)
values = summary_df['Death Numbers']
key_val_pairs = zip(keys, values)
perc_death_map = dict(key_val_pairs)
perc_death_map
# Out:
# {('AFG', 2007): 15.0,
#  ('AFG', 2008): 17.0,
#  ('AFG', 2009): 0.0,
#  ('AFG', 2011): 2.0,
#  ('AFG', 2012): 14.0,
#  ('AFG', 2013): 2.0,
#  ('AFG', 2014): 6.0,
#  ('AFG', 2015): 1.0,
#  ('AFG', 2016): 6.0,
#  ('AFG', 1990): nan,
#  ('AFG', 1991): nan,
#  ('AFG', 1992): nan,
#  ('AFG', 1993): nan,
#  ('AFG', 1994): nan,
#  ('AFG', 1995): nan,
#  ('AFG', 1996): nan,
#  ('AFG', 1997): nan,
#  ('AFG', 1998): nan,
#  ('AFG', 1999): nan,
#  ('AFG', 2000): nan,
#  ('AFG', 2001): nan,
#  ('AFG', 2002): nan,
#  ('AFG', 2003): nan,
#  ('AFG', 2004): nan,
#  ('AFG', 2005): nan,
#  ('AFG', 2006): nan,
#  ('AFG', 2010): nan,
#  ('AFG', 2017): nan,
#  ('AFG', 2018): nan,
#  ('AFG', 2019): nan,
#  ('ALB', 1990): nan,
#  ('ALB', 1991): nan,
#  ('ALB', 1992): nan,
#  ('ALB', 1993): nan,
#  ('ALB', 1994): nan,
#  ('ALB', 1995): nan,
#  ('ALB', 1996): nan,
#  ('ALB', 1997): nan,
#  ('ALB', 1998): nan,
#  ('ALB', 1999): nan,
#  ('ALB', 2000): nan,
#  ('ALB', 2001): nan,
#  ('ALB', 2002): nan,
# ...

# %%
summary_df['Death Numbers'].nunique()
# Out:
# 25183

# %%
keys = [summary_df[['Code' , 'Year']]]
values = summary_df['Death Numbers']
perc_death_map = dict(zip(keys, values))
perc_death_map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [93], line 3
#       1 keys = [summary_df[['Code' , 'Year']]]
#       2 values = summary_df['Death Numbers']
# ----> 3 perc_death_map = dict(zip(keys, values))
#       4 perc_death_map
#
# TypeError: unhashable type: 'DataFrame'

# %%
deaths = summary_df[['Code' , 'Year'], 'Death Numbers', 'Causes name']].groupby(['Code', 'Year']).count('Causes name')
deaths.head(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [87], line 1
# ----> 1 deaths = summary_df[['Code', 'Year', 'Death Numbers', 'Causes name']].groupby(['Code', 'Year']).count('Causes name')
#       2 deaths.head(5)
#
# TypeError: GroupBy.count() takes 1 positional argument but 2 were given

# %%
deaths.transform(dict)
# Out:
#                                             Death Numbers
# 0       {0: 2933.0, 1: 15925.0, 2: 481.0, 3: 393.0, 4:...
# 1       {0: 2933.0, 1: 15925.0, 2: 481.0, 3: 393.0, 4:...
# 2       {0: 2933.0, 1: 15925.0, 2: 481.0, 3: 393.0, 4:...
# 3       {0: 2933.0, 1: 15925.0, 2: 481.0, 3: 393.0, 4:...
# 4       {0: 2933.0, 1: 15925.0, 2: 481.0, 3: 393.0, 4:...
# ...                                                   ...
# 201757  {201729: 1450.0, 201730: 12353.0, 201731: 662....
# 201758  {201729: 1450.0, 201730: 12353.0, 201731: 662....
# 201759  {201729: 1450.0, 201730: 12353.0, 201731: 662....
# 201760  {201729: 1450.0, 201730: 12353.0, 201731: 662....
# 201761  {201729: 1450.0, 201730: 12353.0, 201731: 662....
#
# [201762 rows x 1 columns]

# %% [markdown]
# ##### SAVE:

# %%
summary_df.to_csv('../data/Tableau_Tables/T1 Summary.csv', index=False)

# %% [markdown]
# ----
#
# <a name="table-2-global-totals-:"/>
#
# #### TABLE 2 Global Totals:

# %%
globe_df = pd.read_csv('../data/W4P3_ND.csv')
globe_df.head(5)
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                             2933.0
# 1                                             2731.0
# 2                                             2460.0
# 3                                             2327.0
# 4                                             2254.0
#
#    Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)  \
# 0                                            15925.0
# 1                                            16148.0
# ...

# %%
print(len(globe_df.columns))
globe_df.columns
# Out:
# 36
# Index(['Entity', 'Code', 'Year',
#        'Number of executions (Amnesty International)',
#        'Deaths - Meningitis - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Malaria - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Drowning - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)',
#        'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Road injuries - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Lower respiratory infections - Sex: Both - Age: All Ages (Number)',
# ...

# %%
globe_df = globe_df.rename(columns={
    'Deaths - Meningitis - Sex: Both - Age: All Ages (Number)': 'Meningitis'
  , 'Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)': 'Neoplasms'
  , 'Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)': 'Fire, heat, and hot substances'
  , 'Deaths - Malaria - Sex: Both - Age: All Ages (Number)': 'Malaria'
  , 'Deaths - Drowning - Sex: Both - Age: All Ages (Number)': 'Drowning'
  , 'Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)': 'Interpersonal violence'
  , 'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)': 'HIV/AIDS'
  , 'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)': 'Drug use disorders'
  , 'Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number)': 'Tuberculosis'
  , 'Deaths - Road injuries - Sex: Both - Age: All Ages (Number)': 'Road injuries'
  , 'Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)': 'Maternal disorders'
  , 'Deaths - Lower respiratory infections - Sex: Both - Age: All Ages (Number)': 'Lower respiratory infections'
  , 'Deaths - Neonatal disorders - Sex: Both - Age: All Ages (Number)': 'Neonatal disorders'
  , 'Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)': 'Alcohol use disorders'
  , 'Deaths - Exposure to forces of nature - Sex: Both - Age: All Ages (Number)': 'Exposure to forces of nature'
  , 'Deaths - Diarrheal diseases - Sex: Both - Age: All Ages (Number)': 'Diarrheal diseases'
  , 'Deaths - Environmental heat and cold exposure - Sex: Both - Age: All Ages (Number)': 'Environmental heat and cold exposure'
  , 'Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)': 'Nutritional deficiencies'
  , 'Deaths - Self-harm - Sex: Both - Age: All Ages (Number)': 'Self-harm'
  , 'Deaths - Conflict and terrorism - Sex: Both - Age: All Ages (Number)': 'Conflict and terrorism'
  , 'Deaths - Diabetes mellitus - Sex: Both - Age: All Ages (Number)': 'Diabetes mellitus'
  , 'Deaths - Poisonings - Sex: Both - Age: All Ages (Number)': 'Poisonings'
  , 'Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Number)': 'Protein-energy malnutrition'
  , 'Deaths - Cardiovascular diseases - Sex: Both - Age: All Ages (Number)': 'Cardiovascular diseases'
  , 'Deaths - Chronic kidney disease - Sex: Both - Age: All Ages (Number)': 'Chronic kidney disease'
  , 'Deaths - Chronic respiratory diseases - Sex: Both - Age: All Ages (Number)': 'Chronic respiratory diseases'
  , 'Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: All Ages (Number)': 'Cirrhosis and other chronic liver diseases'
  , 'Deaths - Digestive diseases - Sex: Both - Age: All Ages (Number)': 'Digestive diseases'
  , 'Deaths - Acute hepatitis - Sex: Both - Age: All Ages (Number)': 'Acute hepatitis'
  , 'Deaths - Alzheimer\'s disease and other dementias - Sex: Both - Age: All Ages (Number)': 'Alzheimer\'s disease and other dementias'
  , 'Deaths - Parkinson\'s disease - Sex: Both - Age: All Ages (Number)': 'Parkinson\'s disease'
  , 'Number of executions (Amnesty International)': 'Executions'
  , 'Terrorism (deaths)': 'Terrorism'
})
globe_df.head()
# Out:
#         Entity Code  Year Executions  Meningitis  Neoplasms  \
# 0  Afghanistan  AFG  2007         15      2933.0    15925.0
# 1  Afghanistan  AFG  2008         17      2731.0    16148.0
# 2  Afghanistan  AFG  2009          0      2460.0    16383.0
# 3  Afghanistan  AFG  2011          2      2327.0    17094.0
# 4  Afghanistan  AFG  2012         14      2254.0    17522.0
#
#    Fire, heat, and hot substances  Malaria  Drowning  Interpersonal violence  \
# 0                           481.0    393.0    2127.0                  3657.0
# 1                           462.0    255.0    1973.0                  3785.0
# 2                           448.0    239.0    1852.0                  3874.0
# 3                           448.0    390.0    1775.0                  4170.0
# 4                           445.0     94.0    1716.0                  4245.0
#
#    ...  Protein-energy malnutrition  Terrorism  Cardiovascular diseases  \
# ...

# %%
globe_df.shape
# Out:
# (8254, 36)

# %% [markdown]
# ##### SAVE:

# %%
globe_df.to_csv('../data/Tableau_Tables/T2 Globe Totals.csv', index=False)

# %% [markdown]
# ----
#
# <a name="table-3-age-groups-:"/>
#
# #### TABLE 3 Age Groups:

# %%
age_grp_df = pd.read_csv('../data/nd-age-group.csv')
age_grp_df.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - All causes - Sex: Both - Age: 70+ years (Number)  \
# 0                                              34681
# 1                                              35271
# 2                                              35694
# 3                                              36433
# 4                                              37460
#
#    Deaths - All causes - Sex: Both - Age: 50-69 years (Number)  \
# 0                                              40624
# 1                                              41414
# 2                                              41829
# 3                                              42598
# 4                                              43923
#
#    Deaths - All causes - Sex: Both - Age: 15-49 years (Number)  \
# 0                                              22968
# ...

# %%
age_grp_df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - All causes - Sex: Both - Age: 70+ years (Number)',
#        'Deaths - All causes - Sex: Both - Age: 50-69 years (Number)',
#        'Deaths - All causes - Sex: Both - Age: 15-49 years (Number)',
#        'Deaths - All causes - Sex: Both - Age: 5-14 years (Number)',
#        'Deaths - All causes - Sex: Both - Age: Under 5 (Number)'],
#       dtype='object')

# %%
# Rename Headings:
age_grp_df = age_grp_df.rename(columns={
       'Deaths - All causes - Sex: Both - Age: 70+ years (Number)': '70+ years',
       'Deaths - All causes - Sex: Both - Age: 50-69 years (Number)': '50-69 years',
       'Deaths - All causes - Sex: Both - Age: 15-49 years (Number)': '15-49 years',
       'Deaths - All causes - Sex: Both - Age: 5-14 years (Number)': '5-14 years',
       'Deaths - All causes - Sex: Both - Age: Under 5 (Number)': '0-5 years'})
age_grp_df.head(5)
# Out:
#         Entity Code  Year  70+ years  50-69 years  15-49 years  5-14 years  \
# 0  Afghanistan  AFG  1990      34681        40624        22968        5642
# 1  Afghanistan  AFG  1991      35271        41414        26523        6433
# 2  Afghanistan  AFG  1992      35694        41829        30000        6854
# 3  Afghanistan  AFG  1993      36433        42598        32339        7206
# 4  Afghanistan  AFG  1994      37460        43923        36817        8106
#
#    0-5 years
# 0      78170
# 1      83035
# 2      93859
# 3     106537
# 4     115334

# %%
age_grp_df.shape
# Out:
# (6840, 8)

# %% [markdown]
# ##### SAVE:

# %%
age_grp_df.to_csv('../data/Tableau_Tables/T3 Age Groups.csv', index=False)

# %% [markdown]
# ----

# %% [markdown]
# <a name="table-4-ages-0-4-:"/>
#
# #### TABLE 4 Ages 0-4:

# %%
yr0_4_df = pd.read_csv('../data/nd-0-4-year-olds.csv')
yr0_4_df.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Invasive Non-typhoidal Salmonella (iNTS) - Sex: Both - Age: Under 5 (Number)  \
# 0                                                 48
# 1                                                 55
# 2                                                 68
# 3                                                 78
# 4                                                 83
#
#    Deaths - Interpersonal violence - Sex: Both - Age: Under 5 (Number)  \
# 0                                                105
# 1                                                130
# 2                                                155
# 3                                                178
# 4                                                194
#
#    Deaths - Nutritional deficiencies - Sex: Both - Age: Under 5 (Number)  \
# ...

# %%
yr0_4_df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - Invasive Non-typhoidal Salmonella (iNTS) - Sex: Both - Age: Under 5 (Number)',
#        'Deaths - Interpersonal violence - Sex: Both - Age: Under 5 (Number)',
#        'Deaths - Nutritional deficiencies - Sex: Both - Age: Under 5 (Number)',
#        'Deaths - Acute hepatitis - Sex: Both - Age: Under 5 (Number)',
#        'Deaths - Neoplasms - Sex: Both - Age: Under 5 (Number)',
#        'Deaths - Measles - Sex: Both - Age: Under 5 (Number)',
#        'Deaths - Digestive diseases - Sex: Both - Age: Under 5 (Number)',
#        'Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: Under 5 (Number)',
#        'Deaths - Chronic kidney disease - Sex: Both - Age: Under 5 (Number)',
#        'Deaths - Cardiovascular diseases - Sex: Both - Age: Under 5 (Number)',
#        'Deaths - Congenital birth defects - Sex: Both - Age: Under 5 (Number)',
# ...

# %%
yr0_4_df = yr0_4_df.rename(columns = {
      'Deaths - Invasive Non-typhoidal Salmonella (iNTS) - Sex: Both - Age: Under 5 (Number)': 'Invasive Non-typhoidal Salmonella (iNTS)'
    , 'Deaths - Interpersonal violence - Sex: Both - Age: Under 5 (Number)': 'Interpersonal violence'
    , 'Deaths - Nutritional deficiencies - Sex: Both - Age: Under 5 (Number)': 'Nutritional deficiencies'
    , 'Deaths - Acute hepatitis - Sex: Both - Age: Under 5 (Number)': 'Acute hepatitis'
    , 'Deaths - Neoplasms - Sex: Both - Age: Under 5 (Number)': 'Neoplasms'
    , 'Deaths - Measles - Sex: Both - Age: Under 5 (Number)': 'Measles'
    , 'Deaths - Digestive diseases - Sex: Both - Age: Under 5 (Number)': 'Digestive diseases'
    , 'Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: Under 5 (Number)': 'Cirrhosis and other chronic liver diseases'
    , 'Deaths - Chronic kidney disease - Sex: Both - Age: Under 5 (Number)': 'Chronic kidney disease'
    , 'Deaths - Cardiovascular diseases - Sex: Both - Age: Under 5 (Number)': 'Cardiovascular diseases'
    , 'Deaths - Congenital birth defects - Sex: Both - Age: Under 5 (Number)': 'Congenital birth defects'
    , 'Deaths - Lower respiratory infections - Sex: Both - Age: Under 5 (Number)': 'Lower respiratory infections'
    , 'Deaths - Neonatal preterm birth - Sex: Both - Age: Under 5 (Number)': 'Neonatal preterm birth'
    , 'Deaths - Environmental heat and cold exposure - Sex: Both - Age: Under 5 (Number)': 'Environmental heat and cold exposure'
    , 'Deaths - Neonatal sepsis and other neonatal infections - Sex: Both - Age: Under 5 (Number)': 'Neonatal sepsis and other neonatal infections'
    , 'Deaths - Exposure to forces of nature - Sex: Both - Age: Under 5 (Number)': 'Exposure to forces of nature'
    , 'Deaths - Diabetes mellitus - Sex: Both - Age: Under 5 (Number)': 'Diabetes mellitus'
    , 'Deaths - Neonatal encephalopathy due to birth asphyxia and trauma - Sex: Both - Age: Under 5 (Number)': 'Neonatal encephalopathy due to birth asphyxia and trauma'
    , 'Deaths - Meningitis - Sex: Both - Age: Under 5 (Number)': 'Meningitis'
    , 'Deaths - Other neonatal disorders - Sex: Both - Age: Under 5 (Number)': 'Other neonatal disorders'
    , 'Deaths - Whooping cough - Sex: Both - Age: Under 5 (Number)': 'Whooping cough'
    , 'Deaths - Diarrheal diseases - Sex: Both - Age: Under 5 (Number)': 'Diarrheal diseases'
    , 'Deaths - Fire, heat, and hot substances - Sex: Both - Age: Under 5 (Number)': 'Fire, heat, and hot substances'
    , 'Deaths - Road injuries - Sex: Both - Age: Under 5 (Number)': 'Road injuries'
    , 'Deaths - Tuberculosis - Sex: Both - Age: Under 5 (Number)': 'Tuberculosis'
    , 'Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Number)': 'HIV/AIDS'
    , 'Deaths - Drowning - Sex: Both - Age: Under 5 (Number)': 'Drowning'
    , 'Deaths - Malaria - Sex: Both - Age: Under 5 (Number)': 'Malaria'
    , 'Deaths - Syphilis - Sex: Both - Age: Under 5 (Number)': 'Syphilis'
})
yr0_4_df.head()
# Out:
#         Entity Code  Year  Invasive Non-typhoidal Salmonella (iNTS)  \
# 0  Afghanistan  AFG  1990                                        48
# 1  Afghanistan  AFG  1991                                        55
# 2  Afghanistan  AFG  1992                                        68
# 3  Afghanistan  AFG  1993                                        78
# 4  Afghanistan  AFG  1994                                        83
#
#    Interpersonal violence  Nutritional deficiencies  Acute hepatitis  \
# 0                     105                      1779              718
# 1                     130                      1822              741
# 2                     155                      2069              836
# 3                     178                      2427              970
# 4                     194                      2649             1063
#
#    Neoplasms  Measles  Digestive diseases  ...  Other neonatal disorders  \
# ...

# %%
yr0_4_df.shape
# Out:
# (6840, 32)

# %%
yr0_4_df.isnull().sum()
# Out:
# Entity                                                        0
# Code                                                        690
# Year                                                          0
# Invasive Non-typhoidal Salmonella (iNTS)                      0
# Interpersonal violence                                        0
# Nutritional deficiencies                                      0
# Acute hepatitis                                               0
# Neoplasms                                                     0
# Measles                                                       0
# Digestive diseases                                            0
# Cirrhosis and other chronic liver diseases                    0
# Chronic kidney disease                                        0
# Cardiovascular diseases                                       0
# Congenital birth defects                                      0
# Lower respiratory infections                                  0
# ...

# %% [markdown]
# ##### SAVE:

# %%
yr0_4_df.to_csv('data/Tableau_Tables/T4 Ages 0-4.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [66], line 1
# ----> 1 yr0_4_df.to_csv('data/Tableau_Tables/T4 Ages 0-4.csv', index=False)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/base_env/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/base_env/lib/python3.10/site-packages/pandas/core/generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
# ...

# %% [markdown]
# ----

# %% [markdown]
# <a name="table-5-ages-5-14:"/>
#
# #### TABLE 5 Ages 5-14:

# %%
yr5_14_df = pd.read_csv('data/nd-5-14-year-olds.csv')
yr5_14_df.head(5)

# %%
yr5_14_df.columns

# %%
# Rename Headings:
yr5_14_df = yr5_14_df.rename(columns = {
       'Deaths - Self-harm - Sex: Both - Age: 15-49 years (Number)': 'Self-harm',
       'Deaths - Interpersonal violence - Sex: Both - Age: 15-49 years (Number)': 'Interpersonal violence',
       'Deaths - Exposure to forces of nature - Sex: Both - Age: 15-49 years (Number)': 'Exposure to forces of nature',
       'Deaths - Drowning - Sex: Both - Age: 15-49 years (Number)': 'Drowning',
       'Deaths - Environmental heat and cold exposure - Sex: Both - Age: 15-49 years (Number)': 'Environmental heat and cold exposure',
       'Deaths - Diarrheal diseases - Sex: Both - Age: 15-49 years (Number)': 'Diarrheal diseases',
       'Deaths - Road injuries - Sex: Both - Age: 15-49 years (Number)': 'Road injuries',
       'Deaths - Tuberculosis - Sex: Both - Age: 15-49 years (Number)': 'Tuberculosis',
       'Deaths - HIV/AIDS - Sex: Both - Age: 15-49 years (Number)': 'HIV/AIDS',
       'Deaths - Parkinson\'s disease - Sex: Both - Age: 15-49 years (Number)': 'Parkinson\'s disease',
       'Deaths - Malaria - Sex: Both - Age: 15-49 years (Number)': 'Malaria',
       'Deaths - Fire, heat, and hot substances - Sex: Both - Age: 15-49 years (Number)': 'Fire, heat, and hot substances',
       'Deaths - Chronic kidney disease - Sex: Both - Age: 15-49 years (Number)': 'Chronic kidney disease',
       'Deaths - Neoplasms - Sex: Both - Age: 15-49 years (Number)': 'Neoplasms',
       'Deaths - Digestive diseases - Sex: Both - Age: 15-49 years (Number)': 'Digestive diseases',
       'Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: 15-49 years (Number)': 'Cirrhosis and other chronic liver diseases',
       'Deaths - Chronic respiratory diseases - Sex: Both - Age: 15-49 years (Number)': 'Chronic respiratory diseases',
       'Deaths - Alzheimer\'s disease and other dementias - Sex: Both - Age: 15-49 years (Number)': 'Alzheimer\'s disease and other dementias',
       'Deaths - Cardiovascular diseases - Sex: Both - Age: 15-49 years (Number)': 'Cardiovascular diseases',
       'Deaths - Nutritional deficiencies - Sex: Both - Age: 15-49 years (Number)': 'Nutritional deficiencies',
       'Deaths - Drug use disorders - Sex: Both - Age: 15-49 years (Number)': 'Drug use disorders',
       'Deaths - Alcohol use disorders - Sex: Both - Age: 15-49 years (Number)': 'Alcohol use disorders',
       'Deaths - Lower respiratory infections - Sex: Both - Age: 15-49 years (Number)': 'Lower respiratory infections',
       'Deaths - Diabetes mellitus - Sex: Both - Age: 15-49 years (Number)': 'Diabetes mellitus',
       'Deaths - Protein-energy malnutrition - Sex: Both - Age: 15-49 years (Number)': 'Protein-energy malnutrition',
       'Deaths - Acute hepatitis - Sex: Both - Age: 15-49 years (Number)': 'Acute hepatitis'})
yr5_14_df.head()

# %% [markdown]
# ##### SAVE:

# %%
yr5_14_df.to_csv('data/Tableau_Tables/T5 Ages 5-14.csv', index=False)

# %% [markdown]
# ----

# %% [markdown]
# <a name="table-6-ages-15-49:"/>
#
# #### TABLE 6 Ages 15-49:

# %%
yr15_49_df = pd.read_csv('data/nd-15-49-year-olds.csv')
yr15_49_df.head(5)

# %%
yr15_49_df.columns

# %%
# Rename Headings:
yr15_49_df = yr15_49_df.rename(columns = {
       'Deaths - Self-harm - Sex: Both - Age: 15-49 years (Number)': 'Self-harm',
       'Deaths - Interpersonal violence - Sex: Both - Age: 15-49 years (Number)': 'Interpersonal violence',
       'Deaths - Exposure to forces of nature - Sex: Both - Age: 15-49 years (Number)': 'Exposure to forces of nature',
       'Deaths - Drowning - Sex: Both - Age: 15-49 years (Number)': 'Drowning',
       'Deaths - Environmental heat and cold exposure - Sex: Both - Age: 15-49 years (Number)': 'Environmental heat and cold exposure',
       'Deaths - Diarrheal diseases - Sex: Both - Age: 15-49 years (Number)': 'Diarrheal diseases',
       'Deaths - Road injuries - Sex: Both - Age: 15-49 years (Number)': 'Road injuries',
       'Deaths - Tuberculosis - Sex: Both - Age: 15-49 years (Number)': 'Tuberculosis',
       'Deaths - HIV/AIDS - Sex: Both - Age: 15-49 years (Number)': 'HIV/AIDS',
       'Deaths - Parkinson\'s disease - Sex: Both - Age: 15-49 years (Number)': 'Parkinson\'s disease',
       'Deaths - Malaria - Sex: Both - Age: 15-49 years (Number)': 'Malaria',
       'Deaths - Fire, heat, and hot substances - Sex: Both - Age: 15-49 years (Number)': 'Fire, heat, and hot substances',
       'Deaths - Chronic kidney disease - Sex: Both - Age: 15-49 years (Number)': 'Chronic kidney disease',
       'Deaths - Neoplasms - Sex: Both - Age: 15-49 years (Number)': 'Neoplasms',
       'Deaths - Digestive diseases - Sex: Both - Age: 15-49 years (Number)': 'Digestive diseases',
       'Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: 15-49 years (Number)': 'Cirrhosis and other chronic liver diseases',
       'Deaths - Chronic respiratory diseases - Sex: Both - Age: 15-49 years (Number)': 'Chronic respiratory diseases',
       'Deaths - Alzheimer\'s disease and other dementias - Sex: Both - Age: 15-49 years (Number)': 'Alzheimer\'s disease and other dementias',
       'Deaths - Cardiovascular diseases - Sex: Both - Age: 15-49 years (Number)': 'Cardiovascular diseases',
       'Deaths - Nutritional deficiencies - Sex: Both - Age: 15-49 years (Number)': 'Nutritional deficiencies',
       'Deaths - Drug use disorders - Sex: Both - Age: 15-49 years (Number)': 'Drug use disorders',
       'Deaths - Alcohol use disorders - Sex: Both - Age: 15-49 years (Number)': 'Alcohol use disorders',
       'Deaths - Lower respiratory infections - Sex: Both - Age: 15-49 years (Number)': 'Lower respiratory infections',
       'Deaths - Diabetes mellitus - Sex: Both - Age: 15-49 years (Number)': 'Diabetes mellitus',
       'Deaths - Protein-energy malnutrition - Sex: Both - Age: 15-49 years (Number)': 'Protein-energy malnutrition',
       'Deaths - Acute hepatitis - Sex: Both - Age: 15-49 years (Number)': 'Acute hepatitis'})
yr15_49_df.head()

# %% [markdown]
# ##### SAVE:

# %%
yr15_49_df.to_csv('data/Tableau_Tables/T6 Ages 15-49.csv', index=False)

# %% [markdown]
# ----

# %% [markdown]
# <a name="table-7-ages-50-69:"/>
#
# #### TABLE 7 Ages 50-69:

# %%
yr50_69_df = pd.read_csv('data/nd-50-69-year-olds.csv')
yr50_69_df.head(5)

# %%
yr50_69_df.columns

# %%
# Rename Headings:
yr50_69_df = yr50_69_df.rename(columns = {
       'Deaths - Self-harm - Sex: Both - Age: 50-69 years (Number)': 'Self-harm',
       'Deaths - Interpersonal violence - Sex: Both - Age: 50-69 years (Number)': 'Interpersonal violence',
       'Deaths - Exposure to forces of nature - Sex: Both - Age: 50-69 years (Number)': 'Exposure to forces of nature',
       'Deaths - Drowning - Sex: Both - Age: 50-69 years (Number)': 'Drowning',
       'Deaths - Environmental heat and cold exposure - Sex: Both - Age: 50-69 years (Number)': 'Environmental heat and cold exposure',
       'Deaths - Diarrheal diseases - Sex: Both - Age: 50-69 years (Number)': 'Diarrheal diseases',
       'Deaths - Road injuries - Sex: Both - Age: 50-69 years (Number)': 'Road injuries',
       'Deaths - Tuberculosis - Sex: Both - Age: 50-69 years (Number)': 'Tuberculosis',
       'Deaths - HIV/AIDS - Sex: Both - Age: 50-69 years (Number)': 'HIV/AIDS',
       'Deaths - Parkinson\'s disease - Sex: Both - Age: 50-69 years (Number)': 'Parkinson\'s disease',
       'Deaths - Malaria - Sex: Both - Age: 50-69 years (Number)': 'Malaria',
       'Deaths - Fire, heat, and hot substances - Sex: Both - Age: 50-69 years (Number)': 'Fire, heat, and hot substances',
       'Deaths - Chronic kidney disease - Sex: Both - Age: 50-69 years (Number)': 'Chronic kidney disease',
       'Deaths - Neoplasms - Sex: Both - Age: 50-69 years (Number)': 'Neoplasms',
       'Deaths - Digestive diseases - Sex: Both - Age: 50-69 years (Number)': 'Digestive diseases',
       'Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: 50-69 years (Number)': 'Cirrhosis and other chronic liver diseases',
       'Deaths - Chronic respiratory diseases - Sex: Both - Age: 50-69 years (Number)': 'Chronic respiratory diseases',
       'Deaths - Alzheimer\'s disease and other dementias - Sex: Both - Age: 50-69 years (Number)': 'Alzheimer\'s disease and other dementias',
       'Deaths - Cardiovascular diseases - Sex: Both - Age: 50-69 years (Number)': 'Cardiovascular diseases',
       'Deaths - Nutritional deficiencies - Sex: Both - Age: 50-69 years (Number)': 'Nutritional deficiencies',
       'Deaths - Drug use disorders - Sex: Both - Age: 50-69 years (Number)': 'Drug use disorders',
       'Deaths - Alcohol use disorders - Sex: Both - Age: 50-69 years (Number)': 'Alcohol use disorders',
       'Deaths - Lower respiratory infections - Sex: Both - Age: 50-69 years (Number)': 'Lower respiratory infections',
       'Deaths - Diabetes mellitus - Sex: Both - Age: 50-69 years (Number)': 'Diabetes mellitus',
       'Deaths - Protein-energy malnutrition - Sex: Both - Age: 50-69 years (Number)': 'Protein-energy malnutrition',
       'Deaths - Acute hepatitis - Sex: Both - Age: 50-69 years (Number)': 'Acute hepatitis'})
yr50_69_df.head()

# %% [markdown]
# ##### SAVE:

# %%
yr50_69_df.to_csv('data/Tableau_Tables/T7 Ages 50-69.csv', index=False)

# %% [markdown]
# ----

# %% [markdown]
# <a name="table-8-ages-70+:"/>
#
# #### TABLE 8 Ages 70+:

# %%
yr70_up_df = pd.read_csv('data/nd-70-year-olds.csv')
yr70_up_df.head(5)

# %%
# Preserve data in old headings:
yr70_up_df_columns = yr70_up_df.columns
yr70_up_df_columns

# %%
# Rename Headings:
yr70_up_df = yr70_up_df.rename(columns = {
       'Deaths - Self-harm - Sex: Both - Age: 70+ years (Number)': 'Self-harm',
       'Deaths - Interpersonal violence - Sex: Both - Age: 70+ years (Number)': 'Interpersonal violence',
       'Deaths - Exposure to forces of nature - Sex: Both - Age: 70+ years (Number)': 'Exposure to forces of nature',
       'Deaths - Drowning - Sex: Both - Age: 70+ years (Number)': 'Drowning',
       'Deaths - Environmental heat and cold exposure - Sex: Both - Age: 70+ years (Number)': 'Environmental heat and cold exposure',
       'Deaths - Diarrheal diseases - Sex: Both - Age: 70+ years (Number)': 'Diarrheal diseases',
       'Deaths - Road injuries - Sex: Both - Age: 70+ years (Number)': 'Road injuries',
       'Deaths - Tuberculosis - Sex: Both - Age: 70+ years (Number)': 'Tuberculosis',
       'Deaths - HIV/AIDS - Sex: Both - Age: 70+ years (Number)': 'HIV/AIDS',
       'Deaths - Parkinson\'s disease - Sex: Both - Age: 70+ years (Number)': 'Parkinson\'s disease',
       'Deaths - Malaria - Sex: Both - Age: 70+ years (Number)': 'Malaria',
       'Deaths - Fire, heat, and hot substances - Sex: Both - Age: 70+ years (Number)': 'Fire, heat, and hot substances',
       'Deaths - Chronic kidney disease - Sex: Both - Age: 70+ years (Number)': 'Chronic kidney disease',
       'Deaths - Neoplasms - Sex: Both - Age: 70+ years (Number)': 'Neoplasms',
       'Deaths - Digestive diseases - Sex: Both - Age: 70+ years (Number)': 'Digestive diseases',
       'Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: 70+ years (Number)': 'Cirrhosis and other chronic liver diseases',
       'Deaths - Chronic respiratory diseases - Sex: Both - Age: 70+ years (Number)': 'Chronic respiratory diseases',
       'Deaths - Alzheimer\'s disease and other dementias - Sex: Both - Age: 70+ years (Number)': 'Alzheimer\'s disease and other dementias',
       'Deaths - Cardiovascular diseases - Sex: Both - Age: 70+ years (Number)': 'Cardiovascular diseases',
       'Deaths - Nutritional deficiencies - Sex: Both - Age: 70+ years (Number)': 'Nutritional deficiencies',
       'Deaths - Drug use disorders - Sex: Both - Age: 70+ years (Number)': 'Drug use disorders',
       'Deaths - Alcohol use disorders - Sex: Both - Age: 70+ years (Number)': 'Alcohol use disorders',
       'Deaths - Lower respiratory infections - Sex: Both - Age: 70+ years (Number)': 'Lower respiratory infections',
       'Deaths - Diabetes mellitus - Sex: Both - Age: 70+ years (Number)': 'Diabetes mellitus',
       'Deaths - Protein-energy malnutrition - Sex: Both - Age: 70+ years (Number)': 'Protein-energy malnutrition',
       'Deaths - Acute hepatitis - Sex: Both - Age: 70+ years (Number)': 'Acute hepatitis'})
yr70_up_df.head()

# %% [markdown]
# >STRETCH: I might come back and organize the types of deaths later.

# %% [markdown]
# ##### SAVE:

# %%
yr70_up_df.to_csv('data/Tableau_Tables/T8 Ages 70+.csv', index=False)

# %% [markdown]
# ----

# %% [markdown]
# <a name="table-9-risks:"/>
#
# #### TABLE 9 Risks:

# %%
risk_df = pd.read_csv('data/nd-risk-factor.csv')
risk_df.head(5)

# %%
print(len(risk_df.columns))
risk_df.columns[15:]

# %%
risk_df = risk_df.rename(columns = {
    'Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)': 'Outdoor air pollution - OWID'
  , 'Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)': 'High systolic blood pressure'
  , 'Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)': 'Diet high in sodium'
  , 'Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)': 'Diet low in whole grains'
  , 'Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)': 'Alcohol use'
  , 'Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)': 'Diet low in fruits'
  , 'Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: All Ages (Number)': 'Unsafe water source'
  , 'Deaths - Cause: All causes - Risk: Secondhand smoke - Sex: Both - Age: All Ages (Number)': 'Secondhand smoke'
  , 'Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)': 'Low birth weight'
  , 'Deaths - Cause: All causes - Risk: Child wasting - Sex: Both - Age: All Ages (Number)': 'Child wasting'
  , 'Deaths - Cause: All causes - Risk: Unsafe sex - Sex: Both - Age: All Ages (Number)': 'Unsafe sex'
  , 'Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)': 'Diet low in nuts and seeds'
  , 'Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)': 'Household air pollution from solid fuels'
  , 'Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)': 'Diet low in vegetables'
  , 'Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)': 'Low physical activity'
  , 'Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: All Ages (Number)': 'Smoking'
  , 'Deaths - Cause: All causes - Risk: High fasting plasma glucose - Sex: Both - Age: All Ages (Number)': 'High fasting plasma glucose'
  , 'Deaths - Cause: All causes - Risk: Air pollution - Sex: Both - Age: All Ages (Number)': 'Air pollution'
  , 'Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)': 'High body-mass index'
  , 'Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)': 'Unsafe sanitation'
  , 'Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)': 'No access to handwashing facility'
  , 'Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)': 'Drug use'
  , 'Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)': 'Low bone mineral density'
  , 'Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)': 'Vitamin A deficiency'
  , 'Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)': 'Child stunting'
  , 'Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)': 'Discontinued breastfeeding'
  , 'Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)': 'Non-exclusive breastfeeding'
  , 'Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)': 'Iron deficiency'
})
risk_df.head()

# %% [markdown]
# ##### SAVE:

# %%
risk_df.to_csv('data/Tableau_Tables/T9 Risks.csv', index=False)

# %% [markdown]
# ----
