# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/W4P3_COD_V2.0.csv')
df
# Out:
#                                          Causes name  \
# 0                                         Meningitis
# 1                                          Neoplasms
# 2                     Fire, heat, and hot substances
# 3                                            Malaria
# 4                                           Drowning
# ...                                              ...
# 201757                            Digestive diseases
# 201758                               Acute hepatitis
# 201759       Alzheimer's disease and other dementias
# 201760                           Parkinson's disease
# 201761  Number of executions (Amnesty International)
#
#                                   Causes Full Description  Death Numbers  \
# 0       Deaths - Meningitis - Sex: Both - Age: All Age...         2933.0
# 1       Deaths - Neoplasms - Sex: Both - Age: All Ages...        15925.0
# 2       Deaths - Fire, heat, and hot substances - Sex:...          481.0
# ...

# %%
df = pd.read_csv('data/W4P3_ND.csv')
df.head(5)
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                             2933.0
# 1                                             2731.0
# 2                                             2460.0
# 3                                             2327.0
# 4                                             2254.0
#
#    Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)  \
# 0                                            15925.0
# 1                                            16148.0
# ...

# %%
yr5_df = pd.read_csv('data/nd-0-5-year-olds.csv')
yr5_df.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Invasive Non-typhoidal Salmonella (iNTS) - Sex: Both - Age: Under 5 (Number)  \
# 0                                                 48
# 1                                                 55
# 2                                                 68
# 3                                                 78
# 4                                                 83
#
#    Deaths - Interpersonal violence - Sex: Both - Age: Under 5 (Number)  \
# 0                                                105
# 1                                                130
# 2                                                155
# 3                                                178
# 4                                                194
#
#    Deaths - Nutritional deficiencies - Sex: Both - Age: Under 5 (Number)  \
# ...

# %%
yr15_49_df = pd.read_csv('data/nd-15-49-year-olds.csv')
yr15_49_df.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Self-harm - Sex: Both - Age: 15-49 years (Number)  \
# 0                                                482
# 1                                                535
# 2                                                634
# 3                                                716
# 4                                                759
#
#    Deaths - Interpersonal violence - Sex: Both - Age: 15-49 years (Number)  \
# 0                                               1126
# 1                                               1510
# 2                                               1782
# 3                                               2038
# 4                                               2260
#
#    Deaths - Drowning - Sex: Both - Age: 15-49 years (Number)  \
# 0                                                234
# ...

# %%
yr5_14_df = pd.read_csv('data/nd-5-14-year-olds.csv')
yr5_14_df.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Self-harm - Sex: Both - Age: 5-14 years (Number)  \
# 0                                                 12
# 1                                                 12
# 2                                                 14
# 3                                                 15
# 4                                                 15
#
#    Deaths - Interpersonal violence - Sex: Both - Age: 5-14 years (Number)  \
# 0                                                 65
# 1                                                 80
# 2                                                 88
# 3                                                 97
# 4                                                105
#
#    Deaths - Drowning - Sex: Both - Age: 5-14 years (Number)  \
# 0                                                290
# ...

# %%
yr50_69_df = pd.read_csv('data/nd-50-69-year-olds.csv')
yr50_69_df.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Self-harm - Sex: Both - Age: 50-69 years (Number)  \
# 0                                                167
# 1                                                168
# 2                                                171
# 3                                                176
# 4                                                180
#
#    Deaths - Interpersonal violence - Sex: Both - Age: 50-69 years (Number)  \
# 0                                                208
# 1                                                242
# 2                                                235
# 3                                                237
# 4                                                249
#
#    Deaths - Cardiovascular diseases - Sex: Both - Age: 50-69 years (Number)  \
# ...

# %%
yr70__df = pd.read_csv('data/nd-70-year-olds.csv')
yr70__df.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Self-harm - Sex: Both - Age: 70+ years (Number)  \
# 0                                                 35
# 1                                                 35
# 2                                                 36
# 3                                                 37
# 4                                                 38
#
#    Deaths - Interpersonal violence - Sex: Both - Age: 70+ years (Number)  \
# 0                                                 33
# 1                                                 39
# 2                                                 38
# 3                                                 39
# 4                                                 41
#
#    Deaths - Exposure to forces of nature - Sex: Both - Age: 70+ years (Number)  \
# ...

# %%
print('sdf'); print('slkdjf')
# Out:
# sdf
# slkdjf

# %%
age_grp_df.isnull().sum()
# Out:
# Entity                                                           0
# Code                                                           690
# Year                                                             0
# Deaths - All causes - Sex: Both - Age: 70+ years (Number)        0
# Deaths - All causes - Sex: Both - Age: 50-69 years (Number)      0
# Deaths - All causes - Sex: Both - Age: 15-49 years (Number)      0
# Deaths - All causes - Sex: Both - Age: 5-14 years (Number)       0
# Deaths - All causes - Sex: Both - Age: Under 5 (Number)          0
# dtype: int64

# %%
age_grp_df = pd.read_csv('data/nd-age-group.csv')
age_grp_df.head(5)
age_grp_df.rename(columns=
       'Deaths - All causes - Sex: Both - Age: 70+ years (Number)': '70+ years',
       'Deaths - All causes - Sex: Both - Age: 50-69 years (Number)': '50-69 years',
       'Deaths - All causes - Sex: Both - Age: 15-49 years (Number)': '15-49 years',
       'Deaths - All causes - Sex: Both - Age: 5-14 years (Number)': '5-14 years',
       'Deaths - All causes - Sex: Both - Age: Under 5 (Number)': "0-5 years")
age_grp_df.head(5)
# Out:
#   Cell In [35], line 4
#     'Deaths - All causes - Sex: Both - Age: 70+ years (Number)': '70+ years',
#                                                                ^
# SyntaxError: invalid syntax

# %%
risk_df = pd.read_csv('data/nd-risk-factor.csv')
risk_df.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
#
#    Deaths - Invasive Non-typhoidal Salmonella (iNTS) - Sex: Both - Age: Under 5 (Number)  \
# 0                                                 48
# 1                                                 55
# 2                                                 68
# 3                                                 78
#
#    Deaths - Interpersonal violence - Sex: Both - Age: Under 5 (Number)  \
# 0                                                105
# 1                                                130
# 2                                                155
# 3                                                178
#
#    Deaths - Nutritional deficiencies - Sex: Both - Age: Under 5 (Number)  \
# 0                                               1779
# 1                                               1822
# ...

# %%
df = pd.read_csv('data/W4P3_COD_V2.0.csv')
df
# Out:
#                                          Causes name  \
# 0                                         Meningitis
# 1                                          Neoplasms
# 2                     Fire, heat, and hot substances
# 3                                            Malaria
# 4                                           Drowning
# ...                                              ...
# 201757                            Digestive diseases
# 201758                               Acute hepatitis
# 201759       Alzheimer's disease and other dementias
# 201760                           Parkinson's disease
# 201761  Number of executions (Amnesty International)
#
#                                   Causes Full Description  Death Numbers  \
# 0       Deaths - Meningitis - Sex: Both - Age: All Age...         2933.0
# 1       Deaths - Neoplasms - Sex: Both - Age: All Ages...        15925.0
# 2       Deaths - Fire, heat, and hot substances - Sex:...          481.0
# ...

# %%
afg = df[df['Code']=='AFG']
afg[['Year', 'Causes name', 'Death Numbers']].groupby('Year').head(10)
# Out:
#      Year                     Causes name  Death Numbers
# 0    2007                      Meningitis         2933.0
# 1    2007                       Neoplasms        15925.0
# 2    2007  Fire, heat, and hot substances          481.0
# 3    2007                         Malaria          393.0
# 4    2007                        Drowning         2127.0
# ..    ...                             ...            ...
# 962  2019          Interpersonal violence         5015.0
# 963  2019                        HIV/AIDS          318.0
# 964  2019              Drug use disorders          406.0
# 965  2019                    Tuberculosis         3627.0
# 966  2019                   Road injuries         8254.0
#
# [300 rows x 3 columns]
